# %% [markdown]
# # 	Табиғи тілді өңдеу (NLP) – 1
#
# Токенизация, Bag of Words, TF-IDF, сөздердің векторлық көріністері (Word2Vec, GloVe), BERT эмбеддингтері, HuggingFace кітапханасы

# %% [markdown]
# ##
# ![image.png](attachment:image.png)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 

texts = ["I love playing Skyrim", "Scorn is a atmospheric game", "Skyrim has 3000 mods"]

vectorizer = TfidfVectorizer()      

matrix = vectorizer.fit_transform(texts)

print(vectorizer.get_feature_names_out())
print(matrix.toarray())
# Out:
# ['3000' 'atmospheric' 'game' 'has' 'is' 'love' 'mods' 'playing' 'scorn'
#  'skyrim']
# [[0.         0.         0.         0.         0.         0.62276601
#   0.         0.62276601 0.         0.4736296 ]
#  [0.         0.5        0.5        0.         0.5        0.
#   0.         0.         0.5        0.        ]
#  [0.52863461 0.         0.         0.52863461 0.         0.
#   0.52863461 0.         0.         0.40204024]]

# %% [markdown]
# ##
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##
# ![image.png](attachment:image.png)
